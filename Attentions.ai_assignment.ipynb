# %%
# questions
import json
import pandas as pd

# Correct the file name if necessary
file_name = 'Questions.csv'

try:
    # Load questions
    questions = pd.read_csv(file_name)
    print("CSV file loaded successfully!")
     # Display the first few rows to verify
except FileNotFoundError:
    print(f"Error: The file '{file_name}' was not found.")
except pd.errors.EmptyDataError:
    print("Error: The file is empty.")
except pd.errors.ParserError:
    print("Error: There was a problem parsing the file.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# CSV file loaded successfully!

# %%
import json
import zipfile

def load_all_json_files_from_zip(zip_file_path):
    """
    Loads all JSON files from the zip archive and prints their content.

    Args:
    zip_file_path (str): Path to the zip file.

    Returns:
    list: A list of dictionaries containing the JSON data from each file.
    """
    encodings = ['utf-8', 'utf-16', 'utf-16-be', 'utf-16-le', 'latin-1']
    json_data_list = []
    
    try:
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            file_list = z.namelist()
            print("Contents of the zip file:")
            print(file_list)
            for file_name in file_list:
                if file_name.endswith('.json'):
                    print(f"Loading JSON file: {file_name}")
                    with z.open(file_name) as f:
                        for encoding in encodings:
                            try:
                                data = f.read().decode(encoding)
                                json_data = json.loads(data)
                                print(f"JSON file '{file_name}' loaded successfully with encoding '{encoding}'!")
                                print(json.dumps(json_data, indent=4))  # Pretty-print the JSON content
                                json_data_list.append(json_data)
                                break
                            except (UnicodeDecodeError, json.JSONDecodeError) as e:
                                print(f"Error decoding JSON file '{file_name}' with encoding '{encoding}': {e}")
    except FileNotFoundError:
        print(f"Error: The file '{zip_file_path}' was not found.")
    except zipfile.BadZipFile:
        print("Error: The file is not a zip file or it is corrupted.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    return json_data_list

# Define the path to your zip file
zip_file_path = 'DataModel.zip'

# Load all JSON files from the zip archive
all_json_data = load_all_json_files_from_zip(zip_file_path)
print(f"Loaded {len(all_json_data)} JSON files.")
# Out:
# Contents of the zip file:
# ['metrics_table_new/', '__MACOSX/._metrics_table_new', 'metrics_table_new/browsing_history_1.json', '__MACOSX/metrics_table_new/._browsing_history_1.json', 'metrics_table_new/operational_metrics_fact.json', '__MACOSX/metrics_table_new/._operational_metrics_fact.json', 'metrics_table_new/customer_support_0.json', '__MACOSX/metrics_table_new/._customer_support_0.json', 'metrics_table_new/website_performance_fact.json', '__MACOSX/metrics_table_new/._website_performance_fact.json', 'metrics_table_new/customer_support_1.json', '__MACOSX/metrics_table_new/._customer_support_1.json', 'metrics_table_new/browsing_history_0.json', '__MACOSX/metrics_table_new/._browsing_history_0.json', 'metrics_table_new/supply_chain_fact.json', '__MACOSX/metrics_table_new/._supply_chain_fact.json', 'metrics_table_new/wishlist_1.json', '__MACOSX/metrics_table_new/._wishlist_1.json', 'metrics_table_new/customer_activity_0.json', '__MACOSX/metrics_table_new/._customer_activity_0.json', 'metrics_table_new/reviews_1.json', '__MACOSX/metrics_table_new/._reviews_1.json', 'metrics_table_new/product_sales.json', '__MACOSX/metrics_table_new/._product_sales.json', 'metrics_table_new/customer_activity_1.json', '__MACOSX/metrics_table_new/._customer_activity_1.json', 'metrics_table_new/sales_transaction.json', '__MACOSX/metrics_table_new/._sales_transaction.json', 'metrics_table_new/reviews_0.json', '__MACOSX/metrics_table_new/._reviews_0.json', 'metrics_table_new/order_fulfillment_fact.json', '__MACOSX/metrics_table_new/._order_fulfillment_fact.json', 'metrics_table_new/wishlist_0.json', '__MACOSX/metrics_table_new/._wishlist_0.json', 'metrics_table_new/order_details.json', '__MACOSX/metrics_table_new/._order_details.json', 'metrics_table_new/customer_service_fact.json', '__MACOSX/metrics_table_new/._customer_service_fact.json', 'metrics_table_new/customer_search_0.json', '__MACOSX/metrics_table_new/._customer_search_0.json', 'metrics_table_new/customer_search_1.json', '__MACOSX/metrics_table_new/._customer_search_1.json', 'metrics_table_new/customer_interaction_fact.json', '__MACOSX/metrics_table_new/._customer_interaction_fact.json', 'metrics_table_new/shipping_details.json', '__MACOSX/metrics_table_new/._shipping_details.json', 'metrics_table_new/adjustment_details.json', '__MACOSX/metrics_table_new/._adjustment_details.json', 'metrics_table_new/sales_fact.json', '__MACOSX/metrics_table_new/._sales_fact.json', 'metrics_table_new/order.json', '__MACOSX/metrics_table_new/._order.json', 'metrics_table_new/inventory_fact.json', '__MACOSX/metrics_table_new/._inventory_fact.json', 'metrics_table_new/marketing_fact.json', '__MACOSX/metrics_table_new/._marketing_fact.json', 'ecom_tables_and_columns_new_with_dimensions/', '__MACOSX/._ecom_tables_and_columns_new_with_dimensions', 'ecom_tables_and_columns_new_with_dimensions/customer_0.json', '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._customer_0.json', 'ecom_tables_and_columns_new_with_dimensions/customer_address_history_0.json', '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._customer_address_history_0.json', 'ecom_tables_and_columns_new_with_dimensions/customer_address_history_1.json', '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._customer_address_history_1.json', 'ecom_tables_and_columns_new_with_dimensions/customer_1.json', '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._customer_1.json', 'ecom_tables_and_columns_new_with_dimensions/product_category.json', '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category.json', 'ecom_tables_and_columns_new_with_dimensions/product_category_hierarchy.json', '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category_hierarchy.json', 'ecom_tables_and_columns_new_with_dimensions/loyalty_program_0.json', '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._loyalty_program_0.json', 'ecom_tables_and_columns_new_with_dimensions/loyalty_program_1.json', '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._loyalty ...
# Loading JSON file: metrics_table_new/browsing_history_1.json
# JSON file 'metrics_table_new/browsing_history_1.json' loaded successfully with encoding 'utf-8'!
# {
#     "name": "browsing_history_1",
#     "description": "Tracks user browsing behavior and preferences",
#     "primary_key_column": [
#         "user_id",
#         "session_id"
#     ],
#     "clustering_column": [
#         "session_start_time",
#         "page_viewed"
#     ],
#     "partitioning_column": [
#         "session_date"
#     ],
#     "type": "Type 1 Fact Table",
#     "columns": [
#         {
#             "name": "user_id",
#             "description": "Unique identifier for a user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "Y",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "session_id",
#             "description": "Unique identifier for a session",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "Y",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "session_date",
#             "description": "Date of the browsing session",
#             "data_type": "DATE",
#             "format": "YYYY-MM-DD",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "time_dimension_group"
#         },
#         {
#             "name": "session_start_time",
#             "description": "Start time of the browsing session",
#             "data_type": "TIMESTAMP",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "time_dimension_group"
#         },
#         {
#             "name": "page_viewed",
#             "description": "URL of the page viewed",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "content_dimension_group"
#         },
#         {
#             "name": "device_type",
#             "description": "Type of device used for browsing",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "desktop",
#                 "mobile",
#                 "tablet"
#             ],
#             "dimension_group": "device_dimension_group"
#         },
#         {
#             "name": "browser_type",
#             "description": "Type of browser used",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "chrome",
#                 "firefox",
#                 "safari",
#                 "edge",
#                 "other"
#             ],
#             "dimension_group": "device_dimension_group"
#         },
#         {
#             "name": "os_type",
#             "description": "Operating system of the device",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "windows",
#                 "macos",
#                 "linux",
#                 "android",
#                 "ios",
#                 "other"
#             ],
#             "dimension_group": "device_dimension_group"
#         },
#         {
#             "name": "country",
#             "description": "Country of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "geographic_dimension_group"
#         },
#         {
#             "name": "region",
#             "description": "Region of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "geographic_dimension_group"
#         },
#         {
#             "name": "city",
#             "description": "City of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "geographic_dimension_group"
#         },
#         {
#             "name": "zip_code",
#             "description": "Postal code of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "geographic_dimension_group"
#         },
#         {
#             "name": "interests",
#             "description": "Interests of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "behavior_dimension_group"
#         },
#         {
#             "name": "age_group",
#             "description": "Age group of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "18-24",
#                 "25-34",
#                 "35-44",
#                 "45-54",
#                 "55-64",
#                 "65+"
#             ],
#             "dimension_group": "customer_dimension_group"
#         },
#         {
#             "name": "gender",
#             "description": "Gender of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "male",
#                 "female",
#                 "other"
#             ],
#             "dimension_group": "customer_dimension_group"
#         },
#         {
#             "name": "income_range",
#             "description": "Income range of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "low",
#                 "medium",
#                 "high"
#             ],
#             "dimension_group": "customer_dimension_group"
#         },
#         {
#             "name": "education_level",
#             "description": "Education level of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "none",
#                 "high_school",
#                 "bachelor",
#                 "master",
#                 "doctorate"
#             ],
#             "dimension_group": "customer_dimension_group"
#         },
#         {
#             "name": "employment_status",
#             "description": "Employment status of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "employed",
#                 "unemployed",
#                 "self-employed",
#                 "student",
#                 "retired"
#             ],
#             "dimension_group": "customer_dimension_group"
#         },
#         {
#             "name": "marital_status",
#             "description": "Marital status of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "single",
#                 "married",
#                 "divorced",
#                 "widowed"
#             ],
#             "dimension_group": "customer_dimension_group"
#         },
#         {
#             "name": "number_of_sessions",
#             "description": "Total number of sessions by the user",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "behavior_dimension_group"
#         },
#         {
#             "name": "average_session_duration",
#             "description": "Average duration of sessions",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "behavior_dimension_group"
#         },
#         {
#             "name": "total_pages_viewed",
#             "description": "Total pages viewed by the user",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "behavior_dimension_group"
#         },
#         {
#             "name": "most_viewed_category",
#             "description": "Most viewed category by the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "category_dimension_group"
#         },
#         {
#             "name": "last_active_date",
#             "description": "Last active date of the user",
#             "data_type": "DATE",
#             "format": "YYYY-MM-DD",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "time_dimension_group"
#         },
#         {
#             "name": "referrer",
#             "description": "Referrer URL for the session",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "traffic_dimension_group"
#         }
#     ]
# }
# Loading JSON file: __MACOSX/metrics_table_new/._browsing_history_1.json
# Error decoding JSON file '__MACOSX/metrics_table_new/._browsing_history_1.json' with encoding 'utf-8': 'utf-8' codec can't decode byte 0xd4 in position 99: invalid continuation byte
# Error decoding JSON file '__MACOSX/metrics_table_new/._browsing_history_1.json' with encoding 'utf-16': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._browsing_history_1.json' with encoding 'utf-16-be': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._browsing_history_1.json' with encoding 'utf-16-le': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._browsing_history_1.json' with encoding 'latin-1': Expecting value: line 1 column 1 (char 0)
# Loading JSON file: metrics_table_new/operational_metrics_fact.json
# JSON file 'metrics_table_new/operational_metrics_fact.json' loaded successfully with encoding 'utf-8'!
# {
#     "name": "operational_metrics_fact",
#     "description": "Stores daily operational metrics for analysis",
#     "primary_key_column": [
#         "date",
#         "store_id"
#     ],
#     "clustering_column": [
#         "store_id",
#         "product_id"
#     ],
#     "partitioning_column": [
#         "date"
#     ],
#     "type": "Type 1 Fact Table",
#     "Columns": [
#         {
#             "name": "date",
#             "description": "The date of data recording",
#             "data_type": "DATE",
#             "format": "YYYY-MM-DD",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "store_id",
#             "description": "Unique identifier for a store",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "product_id",
#             "description": "Unique identifier for a product",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "sales_volume",
#             "description": "Total sales volume for the product",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "sales_amount",
#             "description": "Total sales amount in USD",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "returns_volume",
#             "description": "Total volume of returned products",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "returns_amount",
#             "description": "Total amount of returns in USD",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "customer_visits",
#             "description": "Number of customer visits",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "new_customers",
#             "description": "Number of new customers acquired",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "repeat_customers",
#             "description": "Number of repeat customers",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "average_basket_size",
#             "description": "Average number of items per basket",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "average_basket_value",
#             "description": "Average value of baskets in USD",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "customer_satisfaction_score",
#             "description": "Average customer satisfaction score",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "stock_outs",
#             "description": "Number of times stock was out",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "inventory_levels",
#             "description": "Current inventory levels",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "promotional_activity",
#             "description": "Type of promotional activity",
#             "data_type": "STRING",
#             "format": "UpperCase",
#             "is_pii_column": "N",
#             "enum": [
#                 "NONE",
#                 "DISCOUNT",
#                 "BUY_ONE_GET_ONE",
#                 "FLASH_SALE"
#             ]
#         },
#         {
#             "name": "weather_conditions",
#             "description": "Weather conditions during the day",
#             "data_type": "STRING",
#             "format": "UpperCase",
#             "is_pii_column": "N",
#             "enum": [
#                 "SUNNY",
#                 "CLOUDY",
#                 "RAINY",
#                 "SNOWY",
#                 "WINDY"
#             ]
#         },
#         {
#             "name": "local_events",
#             "description": "Local events affecting store traffic",
#             "data_type": "STRING",
#             "format": "UpperCase",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "employee_count",
#             "description": "Number of employees working",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "operational_costs",
#             "description": "Total operational costs in USD",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "marketing_spend",
#             "description": "Total marketing spend in USD",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "technology_spend",
#             "description": "Total technology spend in USD",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "rental_costs",
#             "description": "Total rental costs of the store",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "utility_costs",
#             "description": "Total utility costs in USD",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         }
#     ]
# }
# Loading JSON file: __MACOSX/metrics_table_new/._operational_metrics_fact.json
# Error decoding JSON file '__MACOSX/metrics_table_new/._operational_metrics_fact.json' with encoding 'utf-8': 'utf-8' codec can't decode byte 0xd4 in position 99: invalid continuation byte
# Error decoding JSON file '__MACOSX/metrics_table_new/._operational_metrics_fact.json' with encoding 'utf-16': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._operational_metrics_fact.json' with encoding 'utf-16-be': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._operational_metrics_fact.json' with encoding 'utf-16-le': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._operational_metrics_fact.json' with encoding 'latin-1': Expecting value: line 1 column 1 (char 0)
# Loading JSON file: metrics_table_new/customer_support_0.json
# JSON file 'metrics_table_new/customer_support_0.json' loaded successfully with encoding 'utf-8'!
# {
#     "name": "customer_support_0",
#     "description": "Tracks customer support interactions and details",
#     "primary_key_column": [
#         "ticket_id",
#         "customer_id"
#     ],
#     "clustering_column": [
#         "created_date",
#         "customer_id"
#     ],
#     "partitioning_column": [
#         "created_date"
#     ],
#     "type": "Type 1 Fact Table",
#     "columns": [
#         {
#             "name": "ticket_id",
#             "description": "Unique identifier for support ticket",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "customer_id",
#             "description": "Unique identifier for the customer",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "Y",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "created_date",
#             "description": "Date the ticket was created",
#             "data_type": "DATE",
#             "format": "YYYY-MM-DD",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "time_dimension_group"
#         },
#         {
#             "name": "issue_type",
#             "description": "Type of issue reported",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "billing",
#                 "technical",
#                 "product",
#                 "other"
#             ],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "status",
#             "description": "Current status of the ticket",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "open",
#                 "closed",
#                 "pending",
#                 "escalated"
#             ],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "priority",
#             "description": "Priority level of the ticket",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "low",
#                 "medium",
#                 "high",
#                 "urgent"
#             ],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "resolution_time",
#             "description": "Time taken to resolve the ticket",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "agent_id",
#             "description": "Identifier for the support agent",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "feedback_score",
#             "description": "Customer satisfaction score",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "country",
#             "description": "Country of the customer",
#             "data_type": "STRING",
#             "format": "UpperCase",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "geographic_dimension_group"
#         },
#         {
#             "name": "region",
#             "description": "Region of the customer",
#             "data_type": "STRING",
#             "format": "UpperCase",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "geographic_dimension_group"
#         },
#         {
#             "name": "city",
#             "description": "City of the customer",
#             "data_type": "STRING",
#             "format": "UpperCase",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "geographic_dimension_group"
#         },
#         {
#             "name": "device_used",
#             "description": "Device used to contact support",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "desktop",
#                 "laptop",
#                 "tablet",
#                 "mobile"
#             ],
#             "dimension_group": "device_dimension_group"
#         },
#         {
#             "name": "os",
#             "description": "Operating system of the device",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "Windows",
#                 "macOS",
#                 "Linux",
#                 "Android",
#                 "iOS"
#             ],
#             "dimension_group": "device_dimension_group"
#         },
#         {
#             "name": "app_version",
#             "description": "Version of the app used",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "device_dimension_group"
#         },
#         {
#             "name": "contact_method",
#             "description": "Method used to contact support",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "email",
#                 "phone",
#                 "chat",
#                 "social_media"
#             ],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "issue_description",
#             "description": "Detailed description of the issue",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "Y",
#             "enum": [],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "resolution_description",
#             "description": "Detailed description of the resolution",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "Y",
#             "enum": [],
#             "dimension_group": "customer_support_dimension_group"
#         }
#     ]
# }
# Loading JSON file: __MACOSX/metrics_table_new/._customer_support_0.json
# Error decoding JSON file '__MACOSX/metrics_table_new/._customer_support_0.json' with encoding 'utf-8': 'utf-8' codec can't decode byte 0xd4 in position 99: invalid continuation byte
# Error decoding JSON file '__MACOSX/metrics_table_new/._customer_support_0.json' with encoding 'utf-16': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._customer_support_0.json' with encoding 'utf-16-be': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._customer_support_0.json' with encoding 'utf-16-le': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._customer_support_0.json' with encoding 'latin-1': Expecting value: line 1 column 1 (char 0)
# Loading JSON file: metrics_table_new/website_performance_fact.json
# JSON file 'metrics_table_new/website_performance_fact.json' loaded successfully with encoding 'utf-8'!
# {
#     "name": "website_performance_fact",
#     "description": "Tracks daily website performance metrics",
#     "primary_key_column": [
#         "date",
#         "page_id"
#     ],
#     "clustering_column": [
#         "date",
#         "page_id"
#     ],
#     "partitioning_column": [
#         "date"
#     ],
#     "type": "Type 1 Fact Table",
#     "Columns": [
#         {
#             "name": "date",
#             "description": "The date of data collection",
#             "data_type": "DATE",
#             "format": "YYYY-MM-DD",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "page_id",
#             "description": "Unique identifier for a webpage",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "user_sessions",
#             "description": "Total number of user sessions",
#             "data_type": "INT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "page_views",
#             "description": "Total page views",
#             "data_type": "INT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "unique_visitors",
#             "description": "Number of unique visitors",
#             "data_type": "INT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "bounce_rate",
#             "description": "Percentage of visitors who leave",
#             "data_type": "FLOAT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "average_time_on_page",
#             "description": "Average time spent on page in seconds",
#             "data_type": "FLOAT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "conversion_rate",
#             "description": "Percentage of conversions",
#             "data_type": "FLOAT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "exit_rate",
#             "description": "Percentage of exits from this page",
#             "data_type": "FLOAT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "new_visitors",
#             "description": "Number of new visitors",
#             "data_type": "INT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "returning_visitors",
#             "description": "Number of returning visitors",
#             "data_type": "INT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "page_load_time",
#             "description": "Time taken to load the page",
#             "data_type": "FLOAT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "server_response_time",
#             "description": "Server response time in milliseconds",
#             "data_type": "FLOAT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "errors_per_day",
#             "description": "Number of errors occurred per day",
#             "data_type": "INT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "error_rate",
#             "description": "Error rate as a percentage",
#             "data_type": "FLOAT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "ad_clicks",
#             "description": "Number of advertisement clicks",
#             "data_type": "INT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "ad_impressions",
#             "description": "Number of ad impressions",
#             "data_type": "INT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "cost_per_click",
#             "description": "Cost per advertisement click",
#             "data_type": "FLOAT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "revenue_per_visit",
#             "description": "Revenue generated per visit",
#             "data_type": "FLOAT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "search_engine_traffic",
#             "description": "Traffic coming from search engines",
#             "data_type": "INT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "social_media_traffic",
#             "description": "Traffic coming from social media",
#             "data_type": "INT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "landing_page",
#             "description": "First page visited during the session",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "exit_page",
#             "description": "Last page visited during the session",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "bounce_status",
#             "description": "Whether the session was a bounce (single page visit)",
#             "data_type": "BOOLEAN",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "conversion_event",
#             "description": "Event that indicates a conversion was made",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         },
#         {
#             "name": "referral_source",
#             "description": "Source from which the visitor was referred",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": []
#         }
#     ]
# }
# Loading JSON file: __MACOSX/metrics_table_new/._website_performance_fact.json
# Error decoding JSON file '__MACOSX/metrics_table_new/._website_performance_fact.json' with encoding 'utf-8': 'utf-8' codec can't decode byte 0xd4 in position 99: invalid continuation byte
# Error decoding JSON file '__MACOSX/metrics_table_new/._website_performance_fact.json' with encoding 'utf-16': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._website_performance_fact.json' with encoding 'utf-16-be': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._website_performance_fact.json' with encoding 'utf-16-le': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._website_performance_fact.json' with encoding 'latin-1': Expecting value: line 1 column 1 (char 0)
# Loading JSON file: metrics_table_new/customer_support_1.json
# JSON file 'metrics_table_new/customer_support_1.json' loaded successfully with encoding 'utf-8'!
# {
#     "name": "customer_support_1",
#     "description": "Tracks all customer support interactions",
#     "primary_key_column": [
#         "ticket_id",
#         "customer_id"
#     ],
#     "clustering_column": [
#         "created_date",
#         "customer_id"
#     ],
#     "partitioning_column": [
#         "created_date"
#     ],
#     "type": "Type 2 Fact Table",
#     "columns": [
#         {
#             "name": "ticket_id",
#             "description": "Unique identifier for support ticket",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "customer_id",
#             "description": "Identifier for the customer",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "Y",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "created_date",
#             "description": "Date the ticket was created",
#             "data_type": "DATE",
#             "format": "YYYY-MM-DD",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "issue_type",
#             "description": "Type of issue reported",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "billing",
#                 "technical",
#                 "product",
#                 "other"
#             ],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "status",
#             "description": "Current status of the ticket",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "open",
#                 "closed",
#                 "pending",
#                 "escalated"
#             ],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "priority",
#             "description": "Priority level of the ticket",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "low",
#                 "medium",
#                 "high"
#             ],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "assigned_to",
#             "description": "Support agent ticket is assigned to",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "resolution_time",
#             "description": "Time taken to resolve the ticket",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "first_response_time",
#             "description": "Time for first response to ticket",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "customer_satisfaction",
#             "description": "Customer satisfaction rating",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "channel",
#             "description": "Channel through which ticket was raised",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "email",
#                 "phone",
#                 "chat",
#                 "social_media"
#             ],
#             "dimension_group": "channel_dimension_group"
#         },
#         {
#             "name": "last_updated",
#             "description": "Last update timestamp for the ticket",
#             "data_type": "TIMESTAMP",
#             "format": "YYYY-MM-DD HH:MM:SS",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "notes",
#             "description": "Additional notes on the support ticket",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "escalated",
#             "description": "Whether the ticket was escalated",
#             "data_type": "BOOLEAN",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "customer_support_dimension_group"
#         },
#         {
#             "name": "device_used",
#             "description": "Device used by customer for contact",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "desktop",
#                 "mobile",
#                 "tablet",
#                 "other"
#             ],
#             "dimension_group": "device_dimension_group"
#         },
#         {
#             "name": "os_used",
#             "description": "Operating system of the device used",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "Windows",
#                 "macOS",
#                 "Linux",
#                 "Android",
#                 "iOS",
#                 "other"
#             ],
#             "dimension_group": "device_dimension_group"
#         },
#         {
#             "name": "app_version",
#             "description": "Version of the app used, if applicable",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "device_dimension_group"
#         },
#         {
#             "name": "browser_used",
#             "description": "Web browser used to contact support",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "Chrome",
#                 "Firefox",
#                 "Safari",
#                 "Edge",
#                 "other"
#             ],
#             "dimension_group": "device_dimension_group"
#         },
#         {
#             "name": "country",
#             "description": "Country from which the customer contacted",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "geographic_dimension_group"
#         }
#     ]
# }
# Loading JSON file: __MACOSX/metrics_table_new/._customer_support_1.json
# Error decoding JSON file '__MACOSX/metrics_table_new/._customer_support_1.json' with encoding 'utf-8': 'utf-8' codec can't decode byte 0xd4 in position 99: invalid continuation byte
# Error decoding JSON file '__MACOSX/metrics_table_new/._customer_support_1.json' with encoding 'utf-16': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._customer_support_1.json' with encoding 'utf-16-be': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._customer_support_1.json' with encoding 'utf-16-le': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/metrics_table_new/._customer_support_1.json' with encoding 'latin-1': Expecting value: line 1 column 1 (char 0)
# Loading JSON file: metrics_table_new/browsing_history_0.json
# JSON file 'metrics_table_new/browsing_history_0.json' loaded successfully with encoding 'utf-8'!
# {
#     "name": "browsing_history_0",
#     "description": "Tracks user browsing sessions and activities",
#     "primary_key_column": [
#         "session_id",
#         "user_id"
#     ],
#     "clustering_column": [
#         "session_start_time",
#         "user_id"
#     ],
#     "partitioning_column": [
#         "session_date"
#     ],
#     "type": "Type 1 Fact Table",
#     "columns": [
#         {
#             "name": "session_id",
#             "description": "Unique identifier for the session",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "user_id",
#             "description": "Unique identifier for the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "Y",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "session_start_time",
#             "description": "Start time of the browsing session",
#             "data_type": "TIMESTAMP",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "time_dimension_group"
#         },
#         {
#             "name": "session_end_time",
#             "description": "End time of the browsing session",
#             "data_type": "TIMESTAMP",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "time_dimension_group"
#         },
#         {
#             "name": "session_date",
#             "description": "Date of the browsing session",
#             "data_type": "DATE",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "time_dimension_group"
#         },
#         {
#             "name": "page_views",
#             "description": "Number of pages viewed in session",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "traffic_dimension_group"
#         },
#         {
#             "name": "user_agent",
#             "description": "Browser user agent of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "device_dimension_group"
#         },
#         {
#             "name": "ip_address",
#             "description": "IP address of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "Y",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "device_type",
#             "description": "Type of device used for browsing",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "Desktop",
#                 "Mobile",
#                 "Tablet"
#             ],
#             "dimension_group": "device_dimension_group"
#         },
#         {
#             "name": "country",
#             "description": "Country of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "geographic_dimension_group"
#         },
#         {
#             "name": "region",
#             "description": "Region of the user",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "geographic_dimension_group"
#         },
#         {
#             "name": "city",
#             "description": "City of the user",
# ...
#         },
#         {
#             "name": "brand_id",
#             "description": "Identifier for product brand",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_dimension_group"
#         },
#         {
#             "name": "price",
#             "description": "Current price of the product",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_dimension_group"
#         },
#         {
#             "name": "currency",
#             "description": "Currency of the price listed",
#             "data_type": "STRING",
#             "format": "UpperCase",
#             "is_pii_column": "N",
#             "enum": [
#                 "USD",
#                 "EUR",
#                 "GBP",
#                 "JPY"
#             ],
#             "dimension_group": "product_dimension_group"
#         },
#         {
#             "name": "date_updated",
#             "description": "Last update date for the price",
#             "data_type": "DATE",
#             "format": "YYYY-MM-DD",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "discount_percentage",
#             "description": "Discount offered on the product",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_dimension_group"
#         },
#         {
#             "name": "stock_quantity",
#             "description": "Number of items currently in stock",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "inventory_dimension_group"
#         },
#         {
#             "name": "minimum_order_quantity",
#             "description": "Minimum quantity for ordering",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_dimension_group"
#         },
#         {
#             "name": "shipping_cost",
#             "description": "Cost of shipping this product",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_dimension_group"
#         },
#         {
#             "name": "supplier_id",
#             "description": "Identifier for the product supplier",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "inventory_dimension_group"
#         },
#         {
#             "name": "rating_average",
#             "description": "Average rating for the product",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_review_dimension_group"
#         },
#         {
#             "name": "review_count",
#             "description": "Count of reviews for the product",
#             "data_type": "INTEGER",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_review_dimension_group"
#         },
#         {
#             "name": "is_active",
#             "description": "Whether the product is active for sale",
#             "data_type": "BOOLEAN",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "true",
#                 "false"
#             ],
#             "dimension_group": "product_dimension_group"
#         },
#         {
#             "name": "color",
#             "description": "Color of the product",
#             "data_type": "STRING",
#             "format": "CamelCase",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "size",
#             "description": "Size of the product",
#             "data_type": "STRING",
#             "format": "UpperCase",
#             "is_pii_column": "N",
#             "enum": [
#                 "XS",
#                 "S",
#                 "M",
#                 "L",
#                 "XL",
#                 "XXL"
#             ],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "material",
#             "description": "Material of the product",
#             "data_type": "STRING",
#             "format": "CamelCase",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "weight",
#             "description": "Weight of the product in kilograms",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "length",
#             "description": "Length of the product in centimeters",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "width",
#             "description": "Width of the product in centimeters",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "height",
#             "description": "Height of the product in centimeters",
#             "data_type": "FLOAT",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         }
#     ]
# }
# Loading JSON file: __MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category_pricing.json
# Error decoding JSON file '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category_pricing.json' with encoding 'utf-8': 'utf-8' codec can't decode byte 0xfc in position 99: invalid start byte
# Error decoding JSON file '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category_pricing.json' with encoding 'utf-16': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category_pricing.json' with encoding 'utf-16-be': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category_pricing.json' with encoding 'utf-16-le': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category_pricing.json' with encoding 'latin-1': Expecting value: line 1 column 1 (char 0)
# Loading JSON file: ecom_tables_and_columns_new_with_dimensions/product_category_attributes.json
# JSON file 'ecom_tables_and_columns_new_with_dimensions/product_category_attributes.json' loaded successfully with encoding 'utf-8'!
# {
#     "name": "product_category_attributes",
#     "description": "Attributes defining product categories",
#     "primary_key_column": [
#         "category_id",
#         "attribute_id"
#     ],
#     "clustering_column": [
#         "category_id",
#         "attribute_name"
#     ],
#     "partitioning_column": [
#         "last_updated"
#     ],
#     "type": "Type 2 Dimension Table",
#     "columns": [
#         {
#             "name": "category_id",
#             "description": "Unique identifier for the category",
#             "data_type": "INT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "attribute_id",
#             "description": "Unique identifier for the attribute",
#             "data_type": "INT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "attribute_name",
#             "description": "Name of the attribute",
#             "data_type": "STRING",
#             "format": "CamelCase",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "attribute_value",
#             "description": "Value of the attribute",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "attribute_type",
#             "description": "Type of the attribute",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [
#                 "text",
#                 "number",
#                 "date",
#                 "boolean"
#             ],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "is_filterable",
#             "description": "If attribute is filterable",
#             "data_type": "BOOL",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "is_required",
#             "description": "If attribute is required",
#             "data_type": "BOOL",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "display_order",
#             "description": "Display order in the UI",
#             "data_type": "INT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "created_at",
#             "description": "Timestamp of creation",
#             "data_type": "TIMESTAMP",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "updated_at",
#             "description": "Timestamp of last update",
#             "data_type": "TIMESTAMP",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "last_updated",
#             "description": "Last update for partitioning",
#             "data_type": "DATE",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": ""
#         },
#         {
#             "name": "status",
#             "description": "Status of the attribute",
#             "data_type": "STRING",
#             "format": "UpperCase",
#             "is_pii_column": "N",
#             "enum": [
#                 "ACTIVE",
#                 "INACTIVE",
#                 "DEPRECATED"
#             ],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "visibility",
#             "description": "Visibility on the platform",
#             "data_type": "BOOL",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "source_system",
#             "description": "System where attribute originated",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "source_system_dimension_group"
#         },
#         {
#             "name": "default_value",
#             "description": "Default value of the attribute",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "min_value",
#             "description": "Minimum value for numeric attributes",
#             "data_type": "FLOAT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "max_value",
#             "description": "Maximum value for numeric attributes",
#             "data_type": "FLOAT64",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "unit_of_measure",
#             "description": "Unit of measure for the value",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "category_name",
#             "description": "Name of the product category",
#             "data_type": "STRING",
#             "format": "CamelCase",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "category_dimension_group"
#         },
#         {
#             "name": "description",
#             "description": "Description of the attribute",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "content_dimension_group"
#         },
#         {
#             "name": "is_searchable",
#             "description": "If attribute is searchable",
#             "data_type": "BOOL",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "is_comparable",
#             "description": "If attribute is comparable",
#             "data_type": "BOOL",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "is_configurable",
#             "description": "If attribute is configurable",
#             "data_type": "BOOL",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "product_attribute_dimension_group"
#         },
#         {
#             "name": "data_source",
#             "description": "Source of the attribute data",
#             "data_type": "STRING",
#             "format": "",
#             "is_pii_column": "N",
#             "enum": [],
#             "dimension_group": "source_system_dimension_group"
#         }
#     ]
# }
# Loading JSON file: __MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category_attributes.json
# Error decoding JSON file '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category_attributes.json' with encoding 'utf-8': 'utf-8' codec can't decode byte 0xfc in position 99: invalid start byte
# Error decoding JSON file '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category_attributes.json' with encoding 'utf-16': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category_attributes.json' with encoding 'utf-16-be': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category_attributes.json' with encoding 'utf-16-le': Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file '__MACOSX/ecom_tables_and_columns_new_with_dimensions/._product_category_attributes.json' with encoding 'latin-1': Expecting value: line 1 column 1 (char 0)
# Loaded 39 JSON files.

# %%
# reference_table
import json
import pandas as pd

# Correct the file name if necessary
file_name = 'reference-table.csv'

try:
    # Load questions
    reference_table = pd.read_csv(file_name)
    print("CSV file loaded successfully!")
      # Display the first few rows to verify
except FileNotFoundError:
    print(f"Error: The file '{file_name}' was not found.")
except pd.errors.EmptyDataError:
    print("Error: The file is empty.")
except pd.errors.ParserError:
    print("Error: There was a problem parsing the file.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# CSV file loaded successfully!

# %%
import json

# Define the path to your JSON file
json_file_path = 'relationships_minimized.json'

# Load the JSON data
try:
    with open(json_file_path, 'r') as file:
        relationships_data = json.load(file)
    print("JSON file loaded successfully!")
     # Pretty-print the JSON content
except FileNotFoundError:
    print(f"Error: The file '{json_file_path}' was not found.")
except json.JSONDecodeError:
    print("Error: The file could not be parsed as JSON.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# Example usage of the loaded JSON data
# You can now access the relationships_data dictionary
# Out:
# JSON file loaded successfully!

# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# Load pre-trained GPT-2 model and tokenizer
model_name = "gpt2-medium"  # Or any other GPT-2 variant
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Function to generate response based on user question and provided data
def generate_response(question, data_model, reference_table, table_relationships):
    input_text = f"Question: {question}\nData Model: {data_model}\nReference Table: {reference_table}\nTable Relationships: {table_relationships}"
    
    # Encode the input text
    input_ids = tokenizer.encode(input_text, return_tensors="pt", max_length=512, truncation=True)
    
    # Generate response
    with torch.no_grad():
        output = model.generate(input_ids, max_new_tokens=100, num_return_sequences=1)
    
    # Decode and return the response
    response = tokenizer.decode(output[0], skip_special_tokens=True)
    return response

# Example usage
user_question = input("Please type your question: ")  # Prompt the user to input their question
data_model = load_all_json_files_from_zip  # Your Data Model JSON data
reference_table = reference_table  # Your Reference Table data
table_relationships = relationships_data  # Your Table Relationships data

response = generate_response(user_question, data_model, reference_table, table_relationships)
print("Response:", response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 import torch
#       2 from transformers import GPT2Tokenizer, GPT2LMHeadModel
#       4 # Load pre-trained GPT-2 model and tokenizer
#
# ModuleNotFoundError: No module named 'torch'
